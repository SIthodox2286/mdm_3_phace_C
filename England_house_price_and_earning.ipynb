# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import openpyxl 

# Load Data Functions
from load_data import load_house_price_and_earning_by_district

# %%
median_house_price, lower_quatile_house_price, median_earning, lower_quatile_earning = load_house_price_and_earning_by_district()

# %%
lower_quatile_earning.head()
# Out:
#   Region code    Region name Local authority code Local authority name   2002  \
# 0   E12000008     South East            E07000223                 Adur  14157
# 1   E12000002     North West            E07000026            Allerdale  14280
# 2   E12000004  East Midlands            E07000032         Amber Valley  13023
# 3   E12000008     South East            E07000224                 Arun  13596
# 4   E12000004  East Midlands            E07000170             Ashfield  12691
#
#     2003   2004   2005   2006   2007  ...   2011   2012   2013   2014   2015  \
# 0  15628  14823  14343  16243  16557  ...  16217  18059  17574  18001  18289
# 1  13501  14029  14802  15766  15644  ...  16713  17436  17960  19204  18510
# 2  14476  14639  15589  16502  16564  ...  17518  18041  18542  17485  19246
# 3  14835  15575  15529  16107  15986  ...  16921  17207  17075  17015  18163
# 4  14040  14420  14584  15290  15300  ...  15510  16567  16370  17066  17168
#
# ...

# %%
la_names = lower_quatile_earning.loc[:,'Local authority name']
lq_earning_2020 = lower_quatile_earning.loc[:,2020]

objects = list(la_names)
y_pos = np.arange(len(objects))

fig, ax = plt.subplots()
plt.bar(y_pos, list(lq_earning_2020), align='center',width=0.8)
plt.xticks(y_pos, objects)
figure = plt.gcf()
figure.set_size_inches(80,5)
plt.setp(ax.get_xticklabels(), fontsize=10, rotation='vertical')
plt.ylabel('Earning(Pounds)')
plt.title('Lower Quatile Earning by Local Authority Districts(England)')

plt.show()
